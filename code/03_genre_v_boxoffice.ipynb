# %% [markdown]
# # Analysis of Genres Vs. Box Office and Profitability

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sets the display of float variables so they are not in
# scientific notation
pd.options.display.float_format = '{:.2f}'.format

# %%
# entering color palet for visuals
MIC_OR = '#F25022'
MIC_GR = '#7FBA00'
MIC_BL = '#00A4EF'
MIC_YL = '#FFB900'
MIC_GY = '#737373'

microsoft_color_list = [MIC_OR, MIC_GR, MIC_BL, MIC_YL, MIC_GY]

plt.rcParams['axes.prop_cycle'] = plt.cycler(color=microsoft_color_list)

# %%
# !ls
# Out:
# RT.ipynb
# all_data_copy.ipynb
# all_data_preparation.ipynb
# budget_v_profit.ipynb
# data_preparation.ipynb
# genre_v_boxoffice.ipynb
# genre_v_budget.ipynb
# imdb_first_look.ipynb
# talent_v_revenue.ipynb
# the_movies_db_api.ipynb

# %%
# load in the datasets
df_all_data = pd.read_csv('../data/all_data.csv', index_col=0)
df_movie_info = pd.read_csv('../data/movie_info_budget.csv', index_col=0)

# %% [markdown]
# ### Now it's time to take a look at both data frames

# %%
print(df_all_data.shape)
df_all_data.head(10)
# Out:
# (34033, 23)
#     movie_id        primary_title       original_title  start_year  \
# 0  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 1  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 2  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 3  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 4  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 5  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 6  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 7  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 8  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 9  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
#
#                      genres  average_rating  num_votes          persons_name  \
# 0  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 1  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 2  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 3  Adventure,Family,Fantasy            6.50     358813  Helena Bonham Carter
# 4  Adventure,Family,Fantasy            6.50     358813  Helena Bonham Carter
# 5  Adventure,Family,Fantasy            6.50     358813  Helena Bonham Carter
# 6  Adventure,Family,Fantasy            6.50     358813            Tim Burton
# 7  Adventure,Family,Fantasy            6.50     358813            Tim Burton
# 8  Adventure,Family,Fantasy            6.50     358813            Tim Burton
# 9  Adventure,Family,Fantasy            6.50     358813         Anne Hathaway
#
#   persons_job     title_norm_movie_info  ...  production_budget  \
# 0       actor  alice in wonderland 2010  ...          200000000
# 1       actor  alice in wonderland 2010  ...          200000000
# 2       actor  alice in wonderland 2010  ...          200000000
# 3     actress  alice in wonderland 2010  ...          200000000
# 4     actress  alice in wonderland 2010  ...          200000000
# 5     actress  alice in wonderland 2010  ...          200000000
# 6    director  alice in wonderland 2010  ...          200000000
# 7    director  alice in wonderland 2010  ...          200000000
# 8    director  alice in wonderland 2010  ...          200000000
# 9     actress  alice in wonderland 2010  ...          200000000
#
#   domestic_gross worldwide_gross     title_norm_genre_long      genre  \
# 0      334191110      1025491110  alice in wonderland 2010    Fantasy
# 1      334191110      1025491110  alice in wonderland 2010     Family
# 2      334191110      1025491110  alice in wonderland 2010  Adventure
# 3      334191110      1025491110  alice in wonderland 2010    Fantasy
# 4      334191110      1025491110  alice in wonderland 2010     Family
# 5      334191110      1025491110  alice in wonderland 2010  Adventure
# 6      334191110      1025491110  alice in wonderland 2010    Fantasy
# 7      334191110      1025491110  alice in wonderland 2010     Family
# 8      334191110      1025491110  alice in wonderland 2010  Adventure
# 9      334191110      1025491110  alice in wonderland 2010    Fantasy
#
#    new_budget_api new_ww_revenue_api    imdb_id  vote_average  vote_count
# 0    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 1    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 2    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 3    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 4    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 5    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 6    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 7    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 8    200000000.00      1025467110.00  tt1014759          6.60    12255.00
# 9    200000000.00      1025467110.00  tt1014759          6.60    12255.00
#
# [10 rows x 23 columns]

# %%
print(df_movie_info.shape)
df_movie_info.head(10)
# Out:
# (12689, 16)
#     movie_id        primary_title       original_title  start_year  \
# 0  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 1  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 2  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 3  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 4  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 5  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 6  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 7  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 8  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 9  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
#
#                      genres  average_rating  num_votes          persons_name  \
# 0  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 1  Adventure,Family,Fantasy            6.50     358813  Helena Bonham Carter
# 2  Adventure,Family,Fantasy            6.50     358813            Tim Burton
# 3  Adventure,Family,Fantasy            6.50     358813         Anne Hathaway
# 4  Adventure,Family,Fantasy            6.50     358813              Joe Roth
# 5  Adventure,Family,Fantasy            6.50     358813         Lewis Carroll
# 6  Adventure,Family,Fantasy            6.50     358813         Jennifer Todd
# 7  Adventure,Family,Fantasy            6.50     358813          Suzanne Todd
# 8  Adventure,Family,Fantasy            6.50     358813      Linda Woolverton
# 9  Adventure,Family,Fantasy            6.50     358813        Mia Wasikowska
#
#   persons_job                title_norm  id release_date                movie  \
# 0       actor  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 1     actress  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 2    director  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 3     actress  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 4    producer  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 5      writer  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 6    producer  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 7    producer  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 8      writer  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
# 9     actress  alice in wonderland 2010  51  Mar 5, 2010  Alice in Wonderland
#
#    production_budget  domestic_gross  worldwide_gross
# 0          200000000       334191110       1025491110
# 1          200000000       334191110       1025491110
# 2          200000000       334191110       1025491110
# 3          200000000       334191110       1025491110
# 4          200000000       334191110       1025491110
# 5          200000000       334191110       1025491110
# 6          200000000       334191110       1025491110
# 7          200000000       334191110       1025491110
# 8          200000000       334191110       1025491110
# 9          200000000       334191110       1025491110

# %% [markdown]
# #### df_all_data will allow me to look at the individual genres and how they performed against box office and profitability

# %%
# take a look at the columns
df_all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34033 entries, 0 to 34032
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   movie_id               34033 non-null  object
#  1   primary_title          34033 non-null  object
#  2   original_title         34033 non-null  object
#  3   start_year             34033 non-null  int64
#  4   genres                 34033 non-null  object
#  5   average_rating         34033 non-null  float64
#  6   num_votes              34033 non-null  int64
#  7   persons_name           34033 non-null  object
#  8   persons_job            34033 non-null  object
#  9   title_norm_movie_info  34033 non-null  object
#  10  id                     34033 non-null  int64
#  11  release_date           34033 non-null  object
#  12  movie                  34033 non-null  object
#  13  production_budget      34033 non-null  int64
#  14  domestic_gross         34033 non-null  int64
#  15  worldwide_gross        34033 non-null  int64
#  16  title_norm_genre_long  34033 non-null  object
#  17  genre                  34033 non-null  object
#  18  new_budget_api         34033 non-null  float64
#  19  new_ww_revenue_api     34033 non-null  float64
#  20  imdb_id                34033 non-null  object
#  21  vote_average           34033 non-null  float64
#  22  vote_count             34033 non-null  float64
# dtypes: float64(5), int64(6), object(12)
# memory usage: 6.2+ MB

# %%
df_all_data['new_ww_revenue_api'].value_counts()
# Out:
# 0.00            3326
# 158162788.00      60
# 432844677.00      60
# 3020664.00        60
# 14618727.00       60
#                 ...
# 21164799.00        7
# 34522221.00        6
# 61700416.00        6
# 111300.00          4
# 7972967.00         4
# Name: new_ww_revenue_api, Length: 1115, dtype: int64

# %%
df_all_data.loc[df_all_data['new_ww_revenue_api'] == 0]
# Out:
#         movie_id        primary_title       original_title  start_year  \
# 30     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 31     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 32     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 33     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 34     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# ...          ...                  ...                  ...         ...
# 33911  tt7137380            Destroyer            Destroyer        2018
# 33912  tt7137380            Destroyer            Destroyer        2018
# 33913  tt7137380            Destroyer            Destroyer        2018
# 33914  tt7137380            Destroyer            Destroyer        2018
# 33915  tt7137380            Destroyer            Destroyer        2018
#
#                    genres  average_rating  num_votes         persons_name  \
# 30        Fantasy,Singing            6.50          6     James Fotopoulos
# 31        Fantasy,Singing            6.50          6     James Fotopoulos
# 32        Fantasy,Singing            6.50          6  Lauren Nicole Goode
# 33        Fantasy,Singing            6.50          6  Lauren Nicole Goode
# 34        Fantasy,Singing            6.50          6          Nate Archer
# ...                   ...             ...        ...                  ...
# 33911  Action,Crime,Drama            6.20      13683       Sebastian Stan
# 33912  Action,Crime,Drama            6.20      13683       Sebastian Stan
# 33913  Action,Crime,Drama            6.20      13683          Fred Berger
# 33914  Action,Crime,Drama            6.20      13683          Fred Berger
# 33915  Action,Crime,Drama            6.20      13683          Fred Berger
#
#       persons_job     title_norm_movie_info  ...  production_budget  \
# 30       director  alice in wonderland 2010  ...          200000000
# 31       director  alice in wonderland 2010  ...          200000000
# 32        actress  alice in wonderland 2010  ...          200000000
# 33        actress  alice in wonderland 2010  ...          200000000
# 34       composer  alice in wonderland 2010  ...          200000000
# ...           ...                       ...  ...                ...
# 33911       actor            destroyer 2018  ...            9000000
# 33912       actor            destroyer 2018  ...            9000000
# 33913    producer            destroyer 2018  ...            9000000
# 33914    producer            destroyer 2018  ...            9000000
# 33915    producer            destroyer 2018  ...            9000000
#
#       domestic_gross worldwide_gross     title_norm_genre_long    genre  \
# 30         334191110      1025491110  alice in wonderland 2010  Fantasy
# 31         334191110      1025491110  alice in wonderland 2010  Singing
# 32         334191110      1025491110  alice in wonderland 2010  Fantasy
# 33         334191110      1025491110  alice in wonderland 2010  Singing
# 34         334191110      1025491110  alice in wonderland 2010  Fantasy
# ...              ...             ...                       ...      ...
# 33911        1533324         3681096            destroyer 2018    Crime
# 33912        1533324         3681096            destroyer 2018   Action
# 33913        1533324         3681096            destroyer 2018    Drama
# 33914        1533324         3681096            destroyer 2018    Crime
# 33915        1533324         3681096            destroyer 2018   Action
#
#        new_budget_api new_ww_revenue_api    imdb_id  vote_average  vote_count
# 30               0.00               0.00  tt2049386          6.50        2.00
# 31               0.00               0.00  tt2049386          6.50        2.00
# 32               0.00               0.00  tt2049386          6.50        2.00
# 33               0.00               0.00  tt2049386          6.50        2.00
# 34               0.00               0.00  tt2049386          6.50        2.00
# ...               ...                ...        ...           ...         ...
# 33911      9000000.00               0.00  tt7137380          5.90      580.00
# 33912      9000000.00               0.00  tt7137380          5.90      580.00
# 33913      9000000.00               0.00  tt7137380          5.90      580.00
# 33914      9000000.00               0.00  tt7137380          5.90      580.00
# 33915      9000000.00               0.00  tt7137380          5.90      580.00
#
# [3326 rows x 23 columns]

# %%
df_all_data['worldwide_gross'].value_counts()
# Out:
# 0            1313
# 14618727       60
# 81831866       60
# 652127828      60
# 532938302      60
#              ...
# 433588          6
# 1109276         4
# 9082906         4
# 6653715         3
# 8374            1
# Name: worldwide_gross, Length: 1213, dtype: int64

# %% [markdown]
# #### Important to note that the new_ww_revenue_api has the latest numbers for worldwide revenue but there are more 0 values than the old worldwide_gross. So I will create a new column 'worldwide_gross_final' the will use the 'worldwide_gross' value if the 'new_ww_revenue_api' is equal to 0.

# %%
# creating new 'worldwide_gross_final' column
df_all_data['worldwide_gross_final'] = np.where(df_all_data['new_ww_revenue_api'] == 0,
                                               df_all_data['worldwide_gross'],
                                               df_all_data['new_ww_revenue_api'])

# %%
# check out the new column. it looks good
df_all_data
# Out:
#         movie_id        primary_title       original_title  start_year  \
# 0      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 1      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 2      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 3      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 4      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# ...          ...                  ...                  ...         ...
# 34028  tt3829266         The Predator         The Predator        2018
# 34029  tt3829266         The Predator         The Predator        2018
# 34030  tt3829266         The Predator         The Predator        2018
# 34031  tt3829266         The Predator         The Predator        2018
# 34032  tt3829266         The Predator         The Predator        2018
#
#                          genres  average_rating  num_votes  \
# 0      Adventure,Family,Fantasy            6.50     358813
# 1      Adventure,Family,Fantasy            6.50     358813
# 2      Adventure,Family,Fantasy            6.50     358813
# 3      Adventure,Family,Fantasy            6.50     358813
# 4      Adventure,Family,Fantasy            6.50     358813
# ...                         ...             ...        ...
# 34028   Action,Adventure,Sci-Fi            5.40      94888
# 34029   Action,Adventure,Sci-Fi            5.40      94888
# 34030   Action,Adventure,Sci-Fi            5.40      94888
# 34031   Action,Adventure,Sci-Fi            5.40      94888
# 34032   Action,Adventure,Sci-Fi            5.40      94888
#
#                persons_name persons_job     title_norm_movie_info  ...  \
# 0               Johnny Depp       actor  alice in wonderland 2010  ...
# 1               Johnny Depp       actor  alice in wonderland 2010  ...
# 2               Johnny Depp       actor  alice in wonderland 2010  ...
# 3      Helena Bonham Carter     actress  alice in wonderland 2010  ...
# 4      Helena Bonham Carter     actress  alice in wonderland 2010  ...
# ...                     ...         ...                       ...  ...
# 34028        Jacob Tremblay       actor         the predator 2018  ...
# 34029        Jacob Tremblay       actor         the predator 2018  ...
# 34030       Trevante Rhodes       actor         the predator 2018  ...
# 34031       Trevante Rhodes       actor         the predator 2018  ...
# 34032       Trevante Rhodes       actor         the predator 2018  ...
#
#        domestic_gross worldwide_gross     title_norm_genre_long      genre  \
# 0           334191110      1025491110  alice in wonderland 2010    Fantasy
# 1           334191110      1025491110  alice in wonderland 2010     Family
# 2           334191110      1025491110  alice in wonderland 2010  Adventure
# 3           334191110      1025491110  alice in wonderland 2010    Fantasy
# 4           334191110      1025491110  alice in wonderland 2010     Family
# ...               ...             ...                       ...        ...
# 34028        51024708       159487563         the predator 2018     Action
# 34029        51024708       159487563         the predator 2018  Adventure
# 34030        51024708       159487563         the predator 2018     Sci-Fi
# 34031        51024708       159487563         the predator 2018     Action
# 34032        51024708       159487563         the predator 2018  Adventure
#
#        new_budget_api  new_ww_revenue_api    imdb_id vote_average  vote_count  \
# 0        200000000.00       1025467110.00  tt1014759         6.60    12255.00
# 1        200000000.00       1025467110.00  tt1014759         6.60    12255.00
# 2        200000000.00       1025467110.00  tt1014759         6.60    12255.00
# 3        200000000.00       1025467110.00  tt1014759         6.60    12255.00
# 4        200000000.00       1025467110.00  tt1014759         6.60    12255.00
# ...               ...                 ...        ...          ...         ...
# 34028     88000000.00        160542134.00  tt3829266         5.60     3786.00
# 34029     88000000.00        160542134.00  tt3829266         5.60     3786.00
# 34030     88000000.00        160542134.00  tt3829266         5.60     3786.00
# 34031     88000000.00        160542134.00  tt3829266         5.60     3786.00
# 34032     88000000.00        160542134.00  tt3829266         5.60     3786.00
#
#        worldwide_gross_final
# 0              1025467110.00
# 1              1025467110.00
# 2              1025467110.00
# 3              1025467110.00
# 4              1025467110.00
# ...                      ...
# 34028           160542134.00
# 34029           160542134.00
# 34030           160542134.00
# 34031           160542134.00
# 34032           160542134.00
#
# [34033 rows x 24 columns]

# %%
# taking a closer look at new column if it worked where
# there are 0s in ww_new_revenue_api
df_all_data.loc[df_all_data['new_ww_revenue_api'] == 0]
# Out:
#         movie_id        primary_title       original_title  start_year  \
# 30     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 31     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 32     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 33     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# 34     tt2049386  Alice in Wonderland  Alice in Wonderland        2010
# ...          ...                  ...                  ...         ...
# 33911  tt7137380            Destroyer            Destroyer        2018
# 33912  tt7137380            Destroyer            Destroyer        2018
# 33913  tt7137380            Destroyer            Destroyer        2018
# 33914  tt7137380            Destroyer            Destroyer        2018
# 33915  tt7137380            Destroyer            Destroyer        2018
#
#                    genres  average_rating  num_votes         persons_name  \
# 30        Fantasy,Singing            6.50          6     James Fotopoulos
# 31        Fantasy,Singing            6.50          6     James Fotopoulos
# 32        Fantasy,Singing            6.50          6  Lauren Nicole Goode
# 33        Fantasy,Singing            6.50          6  Lauren Nicole Goode
# 34        Fantasy,Singing            6.50          6          Nate Archer
# ...                   ...             ...        ...                  ...
# 33911  Action,Crime,Drama            6.20      13683       Sebastian Stan
# 33912  Action,Crime,Drama            6.20      13683       Sebastian Stan
# 33913  Action,Crime,Drama            6.20      13683          Fred Berger
# 33914  Action,Crime,Drama            6.20      13683          Fred Berger
# 33915  Action,Crime,Drama            6.20      13683          Fred Berger
#
#       persons_job     title_norm_movie_info  ...  domestic_gross  \
# 30       director  alice in wonderland 2010  ...       334191110
# 31       director  alice in wonderland 2010  ...       334191110
# 32        actress  alice in wonderland 2010  ...       334191110
# 33        actress  alice in wonderland 2010  ...       334191110
# 34       composer  alice in wonderland 2010  ...       334191110
# ...           ...                       ...  ...             ...
# 33911       actor            destroyer 2018  ...         1533324
# 33912       actor            destroyer 2018  ...         1533324
# 33913    producer            destroyer 2018  ...         1533324
# 33914    producer            destroyer 2018  ...         1533324
# 33915    producer            destroyer 2018  ...         1533324
#
#       worldwide_gross     title_norm_genre_long    genre  new_budget_api  \
# 30         1025491110  alice in wonderland 2010  Fantasy            0.00
# 31         1025491110  alice in wonderland 2010  Singing            0.00
# 32         1025491110  alice in wonderland 2010  Fantasy            0.00
# 33         1025491110  alice in wonderland 2010  Singing            0.00
# 34         1025491110  alice in wonderland 2010  Fantasy            0.00
# ...               ...                       ...      ...             ...
# 33911         3681096            destroyer 2018    Crime      9000000.00
# 33912         3681096            destroyer 2018   Action      9000000.00
# 33913         3681096            destroyer 2018    Drama      9000000.00
# 33914         3681096            destroyer 2018    Crime      9000000.00
# 33915         3681096            destroyer 2018   Action      9000000.00
#
#        new_ww_revenue_api    imdb_id vote_average  vote_count  \
# 30                   0.00  tt2049386         6.50        2.00
# 31                   0.00  tt2049386         6.50        2.00
# 32                   0.00  tt2049386         6.50        2.00
# 33                   0.00  tt2049386         6.50        2.00
# 34                   0.00  tt2049386         6.50        2.00
# ...                   ...        ...          ...         ...
# 33911                0.00  tt7137380         5.90      580.00
# 33912                0.00  tt7137380         5.90      580.00
# 33913                0.00  tt7137380         5.90      580.00
# 33914                0.00  tt7137380         5.90      580.00
# 33915                0.00  tt7137380         5.90      580.00
#
#        worldwide_gross_final
# 30             1025491110.00
# 31             1025491110.00
# 32             1025491110.00
# 33             1025491110.00
# 34             1025491110.00
# ...                      ...
# 33911             3681096.00
# 33912             3681096.00
# 33913             3681096.00
# 33914             3681096.00
# 33915             3681096.00
#
# [3326 rows x 24 columns]

# %% [markdown]
# #### Now I'll do the same thing for the budgets of the movie

# %%
df_all_data['new_budget_api'].value_counts()
# Out:
# 0.00           2297
# 40000000.00    1267
# 20000000.00    1199
# 30000000.00    1194
# 35000000.00    1149
#                ...
# 150000.00         9
# 1900000.00        8
# 5000.00           8
# 600000.00         8
# 225000.00         4
# Name: new_budget_api, Length: 205, dtype: int64

# %%
df_all_data['production_budget'].value_counts()
# Out:
# 20000000    1448
# 40000000    1307
# 10000000    1220
# 35000000    1110
# 30000000    1108
#             ...
# 42000          8
# 45000          7
# 2900000        7
# 400000         6
# 225000         4
# Name: production_budget, Length: 228, dtype: int64

# %% [markdown]
# #### 'new_budget_api' has the updated budgets so if these are 0 I will replace them with the 'production_budget' value

# %% [markdown]
# I will create a new column 'budget_final'

# %%
# creating the final budget column
df_all_data['budget_final'] = np.where(df_all_data['new_budget_api'] == 0,
                                               df_all_data['production_budget'],
                                               df_all_data['new_budget_api'])

# %%
# taking a look at the new column
df_all_data[['movie_id', 'production_budget', 'new_budget_api', 'budget_final']]\
    .loc[df_all_data['new_budget_api'] == 0]
# Out:
#         movie_id  production_budget  new_budget_api  budget_final
# 30     tt2049386          200000000            0.00  200000000.00
# 31     tt2049386          200000000            0.00  200000000.00
# 32     tt2049386          200000000            0.00  200000000.00
# 33     tt2049386          200000000            0.00  200000000.00
# 34     tt2049386          200000000            0.00  200000000.00
# ...          ...                ...             ...           ...
# 33375  tt6182908           80000000            0.00   80000000.00
# 33376  tt6182908           80000000            0.00   80000000.00
# 33377  tt6182908           80000000            0.00   80000000.00
# 33378  tt6182908           80000000            0.00   80000000.00
# 33379  tt6182908           80000000            0.00   80000000.00
#
# [2297 rows x 4 columns]

# %% [markdown]
# #### I'll add a profitability column that will show the difference between worldwide gross and production budget.

# %% [markdown]
# NOTE: Microsoft is a large enough company where they may want to distribute large movies worldwide. This is why I'll gauge profitability based off (worldwide_gross_final - budget_final) rather than (domestic_gross - budget_final)

# %%
# add profitability column to df_all_data
df_all_data['profitability'] = df_all_data['worldwide_gross_final'] - df_all_data['budget_final']

# %%
# take a look at the new column
df_all_data.head()
# Out:
#     movie_id        primary_title       original_title  start_year  \
# 0  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 1  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 2  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 3  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 4  tt1014759  Alice in Wonderland  Alice in Wonderland        2010
#
#                      genres  average_rating  num_votes          persons_name  \
# 0  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 1  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 2  Adventure,Family,Fantasy            6.50     358813           Johnny Depp
# 3  Adventure,Family,Fantasy            6.50     358813  Helena Bonham Carter
# 4  Adventure,Family,Fantasy            6.50     358813  Helena Bonham Carter
#
#   persons_job     title_norm_movie_info  ...     title_norm_genre_long  \
# 0       actor  alice in wonderland 2010  ...  alice in wonderland 2010
# 1       actor  alice in wonderland 2010  ...  alice in wonderland 2010
# 2       actor  alice in wonderland 2010  ...  alice in wonderland 2010
# 3     actress  alice in wonderland 2010  ...  alice in wonderland 2010
# 4     actress  alice in wonderland 2010  ...  alice in wonderland 2010
#
#        genre new_budget_api  new_ww_revenue_api    imdb_id  vote_average  \
# 0    Fantasy   200000000.00       1025467110.00  tt1014759          6.60
# 1     Family   200000000.00       1025467110.00  tt1014759          6.60
# 2  Adventure   200000000.00       1025467110.00  tt1014759          6.60
# 3    Fantasy   200000000.00       1025467110.00  tt1014759          6.60
# 4     Family   200000000.00       1025467110.00  tt1014759          6.60
#
#   vote_count worldwide_gross_final  budget_final  profitability
# 0   12255.00         1025467110.00  200000000.00   825467110.00
# 1   12255.00         1025467110.00  200000000.00   825467110.00
# 2   12255.00         1025467110.00  200000000.00   825467110.00
# 3   12255.00         1025467110.00  200000000.00   825467110.00
# 4   12255.00         1025467110.00  200000000.00   825467110.00
#
# [5 rows x 26 columns]

# %% [markdown]
# #### We don't need the person's name, ratings, and etc.. Only columns we need are ['movie_id', 'genre', 'primary_title', 'budget_final', 'domestic_gross', 'worldwide_gross_final']

# %% [markdown]
# #### Now I need to group by the dataframe in order to get the genres and gross associated with the movie_id. Then from there I can do a final group by to find the average of each genre.

# %%
# we only need the relevant columns for our analysis
relevant_columns = ['movie_id', 
                    'genre', 
                    'primary_title', 
                    'budget_final', 
                    'domestic_gross', 
                    'worldwide_gross_final', 
                    'profitability']
df_all_filtered = df_all_data[relevant_columns].groupby(['movie_id','genre']).mean().reset_index()

# %%
df_all_filtered
# Out:
#        movie_id        genre  budget_final  domestic_gross  \
# 0     tt0249516       Action   65000000.00               0
# 1     tt0249516    Animation   65000000.00               0
# 2     tt0249516       Comedy   65000000.00               0
# 3     tt0359950    Adventure   90000000.00        58236838
# 4     tt0359950       Comedy   90000000.00        58236838
# ...         ...          ...           ...             ...
# 3308  tt7784604      Mystery   10000000.00        44069456
# 3309  tt7959026        Crime   50000000.00       103804407
# 3310  tt7959026        Drama   50000000.00       103804407
# 3311  tt7959026     Thriller   50000000.00       103804407
# 3312  tt8632862  Documentary    5000000.00         6352306
#
#       worldwide_gross_final  profitability
# 0                  73706.00   -64926294.00
# 1                  73706.00   -64926294.00
# 2                  73706.00   -64926294.00
# 3              188133322.00    98133322.00
# 4              188133322.00    98133322.00
# ...                     ...            ...
# 3308            80239658.00    70239658.00
# 3309           174804407.00   124804407.00
# 3310           174804407.00   124804407.00
# 3311           174804407.00   124804407.00
# 3312             6653715.00     1653715.00
#
# [3313 rows x 6 columns]

# %%
df_all_filtered['worldwide_gross_final'].value_counts()
# Out:
# 0.00            143
# 10062896.00       6
# 76196538.00       5
# 64780213.00       5
# 260502115.00      3
#                ...
# 7240000.00        1
# 223652.00         1
# 101758490.00      1
# 2368060.00        1
# 32438988.00       1
# Name: worldwide_gross_final, Length: 1216, dtype: int64

# %% [markdown]
# ### It seems there are a good amount of 0s in the dataframe for worldwide_gross_final

# %% [markdown]
# I'll explore these 0s as they might skew the average gross/profitability for the genres. The 0s in the worldwide gross could mean these movies were not released interanationally or they were only released on streaming applications.

# %%
# first filter the data set by worldwide_gross_final == 0
df_all_filtered.loc[df_all_filtered['worldwide_gross_final'] == 0]
# Out:
#        movie_id     genre  budget_final  domestic_gross  \
# 16    tt0393049    Comedy     300000.00               0
# 17    tt0393049     Drama     300000.00               0
# 18    tt0393049   Romance     300000.00               0
# 66    tt0464054    Horror    1400000.00               0
# 67    tt0464054  Thriller    1400000.00               0
# ...         ...       ...           ...             ...
# 3089  tt5022702  Thriller    1000000.00               0
# 3116  tt5127300    Horror   18000000.00               0
# 3150  tt5519340    Action   90000000.00               0
# 3151  tt5519340     Crime   90000000.00               0
# 3152  tt5519340   Fantasy   90000000.00               0
#
#       worldwide_gross_final  profitability
# 16                     0.00     -300000.00
# 17                     0.00     -300000.00
# 18                     0.00     -300000.00
# 66                     0.00    -1400000.00
# 67                     0.00    -1400000.00
# ...                     ...            ...
# 3089                   0.00    -1000000.00
# 3116                   0.00   -18000000.00
# 3150                   0.00   -90000000.00
# 3151                   0.00   -90000000.00
# 3152                   0.00   -90000000.00
#
# [143 rows x 6 columns]

# %%
# cross reference movie_id into the df_all_data dataframe
df_all_data.loc[df_all_data['movie_id'] == 'tt5519340']
# Out:
#         movie_id primary_title original_title  start_year  \
# 30393  tt5519340        Bright         Bright        2017
# 30394  tt5519340        Bright         Bright        2017
# 30395  tt5519340        Bright         Bright        2017
# 30396  tt5519340        Bright         Bright        2017
# 30397  tt5519340        Bright         Bright        2017
# 30398  tt5519340        Bright         Bright        2017
# 30399  tt5519340        Bright         Bright        2017
# 30400  tt5519340        Bright         Bright        2017
# 30401  tt5519340        Bright         Bright        2017
# 30402  tt5519340        Bright         Bright        2017
# 30403  tt5519340        Bright         Bright        2017
# 30404  tt5519340        Bright         Bright        2017
# 30405  tt5519340        Bright         Bright        2017
# 30406  tt5519340        Bright         Bright        2017
# 30407  tt5519340        Bright         Bright        2017
# 30408  tt5519340        Bright         Bright        2017
# 30409  tt5519340        Bright         Bright        2017
# 30410  tt5519340        Bright         Bright        2017
# 30411  tt5519340        Bright         Bright        2017
# 30412  tt5519340        Bright         Bright        2017
# 30413  tt5519340        Bright         Bright        2017
# 30414  tt5519340        Bright         Bright        2017
# 30415  tt5519340        Bright         Bright        2017
# 30416  tt5519340        Bright         Bright        2017
# 30417  tt5519340        Bright         Bright        2017
# 30418  tt5519340        Bright         Bright        2017
# 30419  tt5519340        Bright         Bright        2017
# 30420  tt5519340        Bright         Bright        2017
# 30421  tt5519340        Bright         Bright        2017
# 30422  tt5519340        Bright         Bright        2017
#
#                      genres  average_rating  num_votes    persons_name  \
# 30393  Action,Crime,Fantasy            6.40     147834      Will Smith
# 30394  Action,Crime,Fantasy            6.40     147834      Will Smith
# 30395  Action,Crime,Fantasy            6.40     147834      Will Smith
# 30396  Action,Crime,Fantasy            6.40     147834      David Ayer
# 30397  Action,Crime,Fantasy            6.40     147834      David Ayer
# 30398  Action,Crime,Fantasy            6.40     147834      David Ayer
# 30399  Action,Crime,Fantasy            6.40     147834   Joel Edgerton
# 30400  Action,Crime,Fantasy            6.40     147834   Joel Edgerton
# 30401  Action,Crime,Fantasy            6.40     147834   Joel Edgerton
# 30402  Action,Crime,Fantasy            6.40     147834      Max Landis
# 30403  Action,Crime,Fantasy            6.40     147834      Max Landis
# 30404  Action,Crime,Fantasy            6.40     147834      Max Landis
# 30405  Action,Crime,Fantasy            6.40     147834     Eric Newman
# 30406  Action,Crime,Fantasy            6.40     147834     Eric Newman
# 30407  Action,Crime,Fantasy            6.40     147834     Eric Newman
# 30408  Action,Crime,Fantasy            6.40     147834    Noomi Rapace
# 30409  Action,Crime,Fantasy            6.40     147834    Noomi Rapace
# 30410  Action,Crime,Fantasy            6.40     147834    Noomi Rapace
# 30411  Action,Crime,Fantasy            6.40     147834   Edgar Ramírez
# 30412  Action,Crime,Fantasy            6.40     147834   Edgar Ramírez
# 30413  Action,Crime,Fantasy            6.40     147834   Edgar Ramírez
# 30414  Action,Crime,Fantasy            6.40     147834    Ted Sarandos
# 30415  Action,Crime,Fantasy            6.40     147834    Ted Sarandos
# 30416  Action,Crime,Fantasy            6.40     147834    Ted Sarandos
# 30417  Action,Crime,Fantasy            6.40     147834     David Sardy
# 30418  Action,Crime,Fantasy            6.40     147834     David Sardy
# 30419  Action,Crime,Fantasy            6.40     147834     David Sardy
# 30420  Action,Crime,Fantasy            6.40     147834  Bryan Unkeless
# 30421  Action,Crime,Fantasy            6.40     147834  Bryan Unkeless
# 30422  Action,Crime,Fantasy            6.40     147834  Bryan Unkeless
#
#       persons_job title_norm_movie_info  ...  title_norm_genre_long    genre  \
# 30393       actor           bright 2017  ...            bright 2017    Crime
# 30394       actor           bright 2017  ...            bright 2017   Action
# 30395       actor           bright 2017  ...            bright 2017  Fantasy
# 30396    director           bright 2017  ...            bright 2017    Crime
# 30397    director           bright 2017  ...            bright 2017   Action
# 30398    director           bright 2017  ...            bright 2017  Fantasy
# 30399       actor           bright 2017  ...            bright 2017    Crime
# 30400       actor           bright 2017  ...            bright 2017   Action
# 30401       actor           bright 2017  ...            bright 2017  Fantasy
# 30402      writer           bright 2017  ...            bright 2017    Crime
# 30403      writer           bright 2017  ...            bright 2017   Action
# 30404      writer           bright 2017  ...            bright 2017  Fantasy
# 30405    producer           bright 2017  ...            bright 2017    Crime
# 30406    producer           bright 2017  ...            bright 2017   Action
# 30407    producer           bright 2017  ...            bright 2017  Fantasy
# 30408     actress           bright 2017  ...            bright 2017    Crime
# 30409     actress           bright 2017  ...            bright 2017   Action
# 30410     actress           bright 2017  ...            bright 2017  Fantasy
# 30411       actor           bright 2017  ...            bright 2017    Crime
# 30412       actor           bright 2017  ...            bright 2017   Action
# 30413       actor           bright 2017  ...            bright 2017  Fantasy
# 30414    producer           bright 2017  ...            bright 2017    Crime
# 30415    producer           bright 2017  ...            bright 2017   Action
# 30416    producer           bright 2017  ...            bright 2017  Fantasy
# 30417    composer           bright 2017  ...            bright 2017    Crime
# 30418    composer           bright 2017  ...            bright 2017   Action
# 30419    composer           bright 2017  ...            bright 2017  Fantasy
# 30420    producer           bright 2017  ...            bright 2017    Crime
# 30421    producer           bright 2017  ...            bright 2017   Action
# 30422    producer           bright 2017  ...            bright 2017  Fantasy
#
#       new_budget_api  new_ww_revenue_api    imdb_id  vote_average vote_count  \
# 30393    90000000.00                0.00  tt5519340          6.20    4929.00
# 30394    90000000.00                0.00  tt5519340          6.20    4929.00
# 30395    90000000.00                0.00  tt5519340          6.20    4929.00
# 30396    90000000.00                0.00  tt5519340          6.20    4929.00
# 30397    90000000.00                0.00  tt5519340          6.20    4929.00
# 30398    90000000.00                0.00  tt5519340          6.20    4929.00
# 30399    90000000.00                0.00  tt5519340          6.20    4929.00
# 30400    90000000.00                0.00  tt5519340          6.20    4929.00
# 30401    90000000.00                0.00  tt5519340          6.20    4929.00
# 30402    90000000.00                0.00  tt5519340          6.20    4929.00
# 30403    90000000.00                0.00  tt5519340          6.20    4929.00
# 30404    90000000.00                0.00  tt5519340          6.20    4929.00
# 30405    90000000.00                0.00  tt5519340          6.20    4929.00
# 30406    90000000.00                0.00  tt5519340          6.20    4929.00
# 30407    90000000.00                0.00  tt5519340          6.20    4929.00
# 30408    90000000.00                0.00  tt5519340          6.20    4929.00
# 30409    90000000.00                0.00  tt5519340          6.20    4929.00
# 30410    90000000.00                0.00  tt5519340          6.20    4929.00
# 30411    90000000.00                0.00  tt5519340          6.20    4929.00
# 30412    90000000.00                0.00  tt5519340          6.20    4929.00
# 30413    90000000.00                0.00  tt5519340          6.20    4929.00
# 30414    90000000.00                0.00  tt5519340          6.20    4929.00
# 30415    90000000.00                0.00  tt5519340          6.20    4929.00
# 30416    90000000.00                0.00  tt5519340          6.20    4929.00
# 30417    90000000.00                0.00  tt5519340          6.20    4929.00
# 30418    90000000.00                0.00  tt5519340          6.20    4929.00
# 30419    90000000.00                0.00  tt5519340          6.20    4929.00
# 30420    90000000.00                0.00  tt5519340          6.20    4929.00
# 30421    90000000.00                0.00  tt5519340          6.20    4929.00
# 30422    90000000.00                0.00  tt5519340          6.20    4929.00
#
#       worldwide_gross_final  budget_final  profitability
# 30393                  0.00   90000000.00   -90000000.00
# 30394                  0.00   90000000.00   -90000000.00
# 30395                  0.00   90000000.00   -90000000.00
# 30396                  0.00   90000000.00   -90000000.00
# 30397                  0.00   90000000.00   -90000000.00
# 30398                  0.00   90000000.00   -90000000.00
# 30399                  0.00   90000000.00   -90000000.00
# 30400                  0.00   90000000.00   -90000000.00
# 30401                  0.00   90000000.00   -90000000.00
# 30402                  0.00   90000000.00   -90000000.00
# 30403                  0.00   90000000.00   -90000000.00
# 30404                  0.00   90000000.00   -90000000.00
# 30405                  0.00   90000000.00   -90000000.00
# 30406                  0.00   90000000.00   -90000000.00
# 30407                  0.00   90000000.00   -90000000.00
# 30408                  0.00   90000000.00   -90000000.00
# 30409                  0.00   90000000.00   -90000000.00
# 30410                  0.00   90000000.00   -90000000.00
# 30411                  0.00   90000000.00   -90000000.00
# 30412                  0.00   90000000.00   -90000000.00
# 30413                  0.00   90000000.00   -90000000.00
# 30414                  0.00   90000000.00   -90000000.00
# 30415                  0.00   90000000.00   -90000000.00
# 30416                  0.00   90000000.00   -90000000.00
# 30417                  0.00   90000000.00   -90000000.00
# 30418                  0.00   90000000.00   -90000000.00
# 30419                  0.00   90000000.00   -90000000.00
# 30420                  0.00   90000000.00   -90000000.00
# 30421                  0.00   90000000.00   -90000000.00
# 30422                  0.00   90000000.00   -90000000.00
#
# [30 rows x 26 columns]

# %% [markdown]
# This movie went to straight to netlfix so it does not have a worldwide gross. I'll drop the zeros from this column and dataframe because Microsoft does not have a streaming platform and they might want to focus on how well movies did at the box office. There are only 143 0s in the dataset so I don't believe this will have much affect on the dataset.

# %%
df_all_filtered = df_all_filtered.loc[df_all_filtered['worldwide_gross_final'] != 0]

# %% [markdown]
# Now I can group the dataframe on genre one more time to get the average budget, domestic gross, worldwide gross, and profitability for each genre.

# %%
genre_numbers = df_all_filtered.groupby('genre').mean().reset_index()

# %%
# this will show the number of observations for each genre
genre_numbers_count = df_all_filtered.groupby('genre').count().reset_index()
genre_numbers_count.sort_values('movie_id', ascending=False)
# Out:
#           genre  movie_id  budget_final  domestic_gross  \
# 7         Drama       572           572             572
# 4        Comedy       452           452             452
# 0        Action       381           381             381
# 1     Adventure       315           315             315
# 18     Thriller       209           209             209
# 5         Crime       191           191             191
# 14      Romance       162           162             162
# 11       Horror       130           130             130
# 15       Sci-Fi       113           113             113
# 9       Fantasy       111           111             111
# 13      Mystery       106           106             106
# 3     Biography       105           105             105
# 2     Animation        92            92              92
# 8        Family        77            77              77
# 12        Music        45            45              45
# 10      History        28            28              28
# 17        Sport        27            27              27
# 6   Documentary        21            21              21
# 19          War        16            16              16
# 20      Western         9             9               9
# 16      Singing         8             8               8
#
#     worldwide_gross_final  profitability
# 7                     572            572
# 4                     452            452
# 0                     381            381
# 1                     315            315
# 18                    209            209
# 5                     191            191
# 14                    162            162
# 11                    130            130
# 15                    113            113
# 9                     111            111
# 13                    106            106
# 3                     105            105
# 2                      92             92
# 8                      77             77
# 12                     45             45
# 10                     28             28
# 17                     27             27
# 6                      21             21
# 19                     16             16
# 20                      9              9
# 16                      8              8

# %% [markdown]
# NOTE: A sample size of less than 30 may be too small for significant results. I'll create a new dataframe without genres with less than 30 observations

# %%
# take a look at the new dataset
genre_numbers
# Out:
#           genre  budget_final  domestic_gross  worldwide_gross_final  \
# 0        Action   85857217.86     98583883.77           267789354.40
# 1     Adventure  111359365.09    134049026.22           376202117.43
# 2     Animation  101782608.70    147567057.25           403221263.11
# 3     Biography   28255905.71     47558662.94            95339849.15
# 4        Comedy   44362157.58     66533610.71           148853000.94
# 5         Crime   35279359.61     43382116.07            92288669.69
# 6   Documentary    4586909.52     16356465.71            20320595.81
# 7         Drama   29713567.94     40308823.51            86434153.23
# 8        Family   74175324.68     90405208.36           221209669.44
# 9       Fantasy   90816222.07     91436305.47           264125704.54
# 10      History   39875000.00     55629164.93           116698033.96
# 11       Horror   21265274.23     38370353.99            83872439.85
# 12        Music   18280002.22     40663761.31            86969873.44
# 13      Mystery   26928915.09     43730092.18           102412699.58
# 14      Romance   22655000.09     38759542.08            77757967.34
# 15       Sci-Fi  102600000.03    141090297.65           387790263.06
# 16      Singing   73006250.00    136402399.50           358938989.88
# 17        Sport   24785185.19     37425999.67            48901150.70
# 18     Thriller   36593899.52     51212708.88           132880251.42
# 19          War   27593750.00     25278345.50            59763013.56
# 20      Western   61033333.33     63729964.67           134439442.89
#
#     profitability
# 0    181932136.54
# 1    264842752.34
# 2    301438654.41
# 3     67083943.44
# 4    104490843.36
# 5     57009310.08
# 6     15733686.29
# 7     56720585.30
# 8    147034344.77
# 9    173309482.47
# 10    76823033.96
# 11    62607165.62
# 12    68689871.22
# 13    75483784.49
# 14    55102967.25
# 15   285190263.04
# 16   285932739.88
# 17    24115965.52
# 18    96286351.90
# 19    32169263.56
# 20    73406109.56

# %% [markdown]
# I'll add a ROI (return on investment column) which will be (profitability / budget_final) * 100

# %%
genre_numbers['roi_%'] = (genre_numbers['profitability'] / genre_numbers['budget_final'])

# %%
genre_numbers
# Out:
#           genre  budget_final  domestic_gross  worldwide_gross_final  \
# 0        Action   85857217.86     98583883.77           267789354.40
# 1     Adventure  111359365.09    134049026.22           376202117.43
# 2     Animation  101782608.70    147567057.25           403221263.11
# 3     Biography   28255905.71     47558662.94            95339849.15
# 4        Comedy   44362157.58     66533610.71           148853000.94
# 5         Crime   35279359.61     43382116.07            92288669.69
# 6   Documentary    4586909.52     16356465.71            20320595.81
# 7         Drama   29713567.94     40308823.51            86434153.23
# 8        Family   74175324.68     90405208.36           221209669.44
# 9       Fantasy   90816222.07     91436305.47           264125704.54
# 10      History   39875000.00     55629164.93           116698033.96
# 11       Horror   21265274.23     38370353.99            83872439.85
# 12        Music   18280002.22     40663761.31            86969873.44
# 13      Mystery   26928915.09     43730092.18           102412699.58
# 14      Romance   22655000.09     38759542.08            77757967.34
# 15       Sci-Fi  102600000.03    141090297.65           387790263.06
# 16      Singing   73006250.00    136402399.50           358938989.88
# 17        Sport   24785185.19     37425999.67            48901150.70
# 18     Thriller   36593899.52     51212708.88           132880251.42
# 19          War   27593750.00     25278345.50            59763013.56
# 20      Western   61033333.33     63729964.67           134439442.89
#
#     profitability  roi_%
# 0    181932136.54   2.12
# 1    264842752.34   2.38
# 2    301438654.41   2.96
# 3     67083943.44   2.37
# 4    104490843.36   2.36
# 5     57009310.08   1.62
# 6     15733686.29   3.43
# 7     56720585.30   1.91
# 8    147034344.77   1.98
# 9    173309482.47   1.91
# 10    76823033.96   1.93
# 11    62607165.62   2.94
# 12    68689871.22   3.76
# 13    75483784.49   2.80
# 14    55102967.25   2.43
# 15   285190263.04   2.78
# 16   285932739.88   3.92
# 17    24115965.52   0.97
# 18    96286351.90   2.63
# 19    32169263.56   1.17
# 20    73406109.56   1.20

# %% [markdown]
# ## Visualizing genre_numbers Dataframe

# %% [markdown]
# ### First I'll visualize worldwide_gross_final

# %%
worldwide_gross = genre_numbers[['genre', 'worldwide_gross_final']]

# %%
worldwide_gross.sort_values('worldwide_gross_final', ascending=False)
# Out:
#           genre  worldwide_gross_final
# 2     Animation           403221263.11
# 15       Sci-Fi           387790263.06
# 1     Adventure           376202117.43
# 16      Singing           358938989.88
# 0        Action           267789354.40
# 9       Fantasy           264125704.54
# 8        Family           221209669.44
# 4        Comedy           148853000.94
# 20      Western           134439442.89
# 18     Thriller           132880251.42
# 10      History           116698033.96
# 13      Mystery           102412699.58
# 3     Biography            95339849.15
# 5         Crime            92288669.69
# 12        Music            86969873.44
# 7         Drama            86434153.23
# 11       Horror            83872439.85
# 14      Romance            77757967.34
# 19          War            59763013.56
# 17        Sport            48901150.70
# 6   Documentary            20320595.81

# %% [markdown]
# Visualize the top 10 genres by worldwide gross

# %%
# top 10 genres by worldwide gross
ww_top_10 = worldwide_gross.nlargest(10, columns='worldwide_gross_final')
print(ww_top_10)
# Out:
#         genre  worldwide_gross_final
# 2   Animation           403221263.11
# 15     Sci-Fi           387790263.06
# 1   Adventure           376202117.43
# 16    Singing           358938989.88
# 0      Action           267789354.40
# 9     Fantasy           264125704.54
# 8      Family           221209669.44
# 4      Comedy           148853000.94
# 20    Western           134439442.89
# 18   Thriller           132880251.42

# %%
# plotting those values in a horizontal bar chart
fig, ax = plt.subplots(figsize=(8,6))

# horizontal bar chart
ax.barh(y=ww_top_10['genre'], width=ww_top_10['worldwide_gross_final']);

# %%
# Plotting it with seaborn

# %%
sns.barplot(data=ww_top_10, y='genre', x='worldwide_gross_final', orient='h');

# %% [markdown]
# ### Next is profitability

# %%
profit_top_10 = genre_numbers[['genre', 'profitability']].nlargest(10,'profitability')
profit_top_10
# Out:
#         genre  profitability
# 2   Animation   301438654.41
# 16    Singing   285932739.88
# 15     Sci-Fi   285190263.04
# 1   Adventure   264842752.34
# 0      Action   181932136.54
# 9     Fantasy   173309482.47
# 8      Family   147034344.77
# 4      Comedy   104490843.36
# 18   Thriller    96286351.90
# 10    History    76823033.96

# %%
# Plotting a horizontal bar chart
sns.barplot(data=profit_top_10, y='genre', x='profitability', orient='h');

# %% [markdown]
# ### Next Plotting Return on Investment

# %%
roi_top_10 = genre_numbers[['genre', 'roi_%']].nlargest(10,'roi_%')
roi_top_10
# Out:
#           genre  roi_%
# 16      Singing   3.92
# 12        Music   3.76
# 6   Documentary   3.43
# 2     Animation   2.96
# 11       Horror   2.94
# 13      Mystery   2.80
# 15       Sci-Fi   2.78
# 18     Thriller   2.63
# 14      Romance   2.43
# 1     Adventure   2.38

# %%
# Plotting on a horizontal bar chart
sns.barplot(data=roi_top_10, y='genre', x='roi_%', orient='h');

# %%
# this will show the number of observations for each genre
genre_numbers_count = df_all_filtered.groupby('genre').count().reset_index()
genre_numbers_count.sort_values('movie_id', ascending=False)
# Out:
#           genre  movie_id  budget_final  domestic_gross  \
# 7         Drama       572           572             572
# 4        Comedy       452           452             452
# 0        Action       381           381             381
# 1     Adventure       315           315             315
# 18     Thriller       209           209             209
# 5         Crime       191           191             191
# 14      Romance       162           162             162
# 11       Horror       130           130             130
# 15       Sci-Fi       113           113             113
# 9       Fantasy       111           111             111
# 13      Mystery       106           106             106
# 3     Biography       105           105             105
# 2     Animation        92            92              92
# 8        Family        77            77              77
# 12        Music        45            45              45
# 10      History        28            28              28
# 17        Sport        27            27              27
# 6   Documentary        21            21              21
# 19          War        16            16              16
# 20      Western         9             9               9
# 16      Singing         8             8               8
#
#     worldwide_gross_final  profitability
# 7                     572            572
# 4                     452            452
# 0                     381            381
# 1                     315            315
# 18                    209            209
# 5                     191            191
# 14                    162            162
# 11                    130            130
# 15                    113            113
# 9                     111            111
# 13                    106            106
# 3                     105            105
# 2                      92             92
# 8                      77             77
# 12                     45             45
# 10                     28             28
# 17                     27             27
# 6                      21             21
# 19                     16             16
# 20                      9              9
# 16                      8              8

# %% [markdown]
# NOTE: A sample size of less than 30 may be too small for significant results. I'll create a new dataframe without genres with less than 30 observations

# %% [markdown]
# I'll get a list of the genres with less than 30 observations and then remove them from the df_all_filtered dataframe. From there I'll group the dataframe again and find the mean of each genre.

# %%
small_genres = genre_numbers_count.loc[genre_numbers_count['movie_id'] < 30]['genre'].values

# %%
# make the small_genres array a list
small_genres = list(small_genres)
small_genres
# Out:
# ['Documentary', 'History', 'Singing', 'Sport', 'War', 'Western']

# %%
'Documentary' in small_genres
# Out:
# True

# %%
df_all_filtered
# Out:
#        movie_id        genre  budget_final  domestic_gross  \
# 0     tt0249516       Action   65000000.00               0
# 1     tt0249516    Animation   65000000.00               0
# 2     tt0249516       Comedy   65000000.00               0
# 3     tt0359950    Adventure   90000000.00        58236838
# 4     tt0359950       Comedy   90000000.00        58236838
# ...         ...          ...           ...             ...
# 3308  tt7784604      Mystery   10000000.00        44069456
# 3309  tt7959026        Crime   50000000.00       103804407
# 3310  tt7959026        Drama   50000000.00       103804407
# 3311  tt7959026     Thriller   50000000.00       103804407
# 3312  tt8632862  Documentary    5000000.00         6352306
#
#       worldwide_gross_final  profitability
# 0                  73706.00   -64926294.00
# 1                  73706.00   -64926294.00
# 2                  73706.00   -64926294.00
# 3              188133322.00    98133322.00
# 4              188133322.00    98133322.00
# ...                     ...            ...
# 3308            80239658.00    70239658.00
# 3309           174804407.00   124804407.00
# 3310           174804407.00   124804407.00
# 3311           174804407.00   124804407.00
# 3312             6653715.00     1653715.00
#
# [3170 rows x 6 columns]

# %%
# I'll filter the df_all_filtered dataset without the small_genres
df_all_most_genres = df_all_filtered.loc[~(df_all_filtered['genre'].isin(small_genres))]

# %%
# Now to find mean of the genres in new dataframe
most_genres = df_all_most_genres.groupby('genre').mean().reset_index()

# %%
# add roi_% column to new dataframe
most_genres['roi_%'] = (most_genres['profitability'] / most_genres['budget_final'])

# %%
most_genres
# Out:
#         genre  budget_final  domestic_gross  worldwide_gross_final  \
# 0      Action   85857217.86     98583883.77           267789354.40
# 1   Adventure  111359365.09    134049026.22           376202117.43
# 2   Animation  101782608.70    147567057.25           403221263.11
# 3   Biography   28255905.71     47558662.94            95339849.15
# 4      Comedy   44362157.58     66533610.71           148853000.94
# 5       Crime   35279359.61     43382116.07            92288669.69
# 6       Drama   29713567.94     40308823.51            86434153.23
# 7      Family   74175324.68     90405208.36           221209669.44
# 8     Fantasy   90816222.07     91436305.47           264125704.54
# 9      Horror   21265274.23     38370353.99            83872439.85
# 10      Music   18280002.22     40663761.31            86969873.44
# 11    Mystery   26928915.09     43730092.18           102412699.58
# 12    Romance   22655000.09     38759542.08            77757967.34
# 13     Sci-Fi  102600000.03    141090297.65           387790263.06
# 14   Thriller   36593899.52     51212708.88           132880251.42
#
#     profitability  roi_%
# 0    181932136.54   2.12
# 1    264842752.34   2.38
# 2    301438654.41   2.96
# 3     67083943.44   2.37
# 4    104490843.36   2.36
# 5     57009310.08   1.62
# 6     56720585.30   1.91
# 7    147034344.77   1.98
# 8    173309482.47   1.91
# 9     62607165.62   2.94
# 10    68689871.22   3.76
# 11    75483784.49   2.80
# 12    55102967.25   2.43
# 13   285190263.04   2.78
# 14    96286351.90   2.63

# %% [markdown]
# ### Redo Visualizing Worldwide Gross

# %%
new_worldwide_gross = most_genres[['genre', 'worldwide_gross_final']].nlargest(10, columns='worldwide_gross_final')
new_worldwide_gross
# Out:
#         genre  worldwide_gross_final
# 2   Animation           403221263.11
# 13     Sci-Fi           387790263.06
# 1   Adventure           376202117.43
# 0      Action           267789354.40
# 8     Fantasy           264125704.54
# 7      Family           221209669.44
# 4      Comedy           148853000.94
# 14   Thriller           132880251.42
# 11    Mystery           102412699.58
# 3   Biography            95339849.15

# %%
# plotting on a horizontal bar
plot = sns.barplot(data=new_worldwide_gross, y='genre', x='worldwide_gross_final', orient='h', color='#00A4EF');

# title and axis labels
plot.set_title("Top 10 Genres by Average Worldwide Gross")
plot.set_xlabel("Revenue (in Millions)")
plot.set_ylabel("")

# This changes the tick labels to show in millions (ex. 50,000,000 -> 50) 
x_tick_labels = ['{:,.0f}'.format(x) for x in plot.get_xticks()/1000000]
plot.set_xticks(plot.get_xticks().tolist())
plot.set_xticklabels(x_tick_labels);

# save plot as jpg
plt.savefig('../Images/Top 10 Genres by Worldwide Gross.jpg', dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Redo Visualization for Profitability

# %%
profit_top_10 = most_genres[['genre', 'profitability']].nlargest(10,'profitability')
profit_top_10
# Out:
#         genre  profitability
# 2   Animation   301438654.41
# 13     Sci-Fi   285190263.04
# 1   Adventure   264842752.34
# 0      Action   181932136.54
# 8     Fantasy   173309482.47
# 7      Family   147034344.77
# 4      Comedy   104490843.36
# 14   Thriller    96286351.90
# 11    Mystery    75483784.49
# 10      Music    68689871.22

# %%
# Plotting a horizontal bar chart
plot = sns.barplot(data=profit_top_10, y='genre', x='profitability', orient='h', color='#00A4EF');

# title and axis labels
plot.set_title("Top 10 Genres by Average Profit")
plot.set_xlabel("Profit (in Millions)")
plot.set_ylabel("")

# This changes the tick labels to show in millions (ex. 50,000,000 -> 50) 
x_tick_labels = ['{:,.0f}'.format(x) for x in plot.get_xticks()/1000000]
plot.set_xticks(plot.get_xticks().tolist())
plot.set_xticklabels(x_tick_labels);

# save plot as jpg
plt.savefig('../Images/Top 10 Genres by Average Profit.jpg', dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Redo Visualization for ROI

# %%
roi_top_10 = most_genres[['genre', 'roi_%']].nlargest(10,'roi_%')
roi_top_10
# Out:
#         genre  roi_%
# 10      Music   3.76
# 2   Animation   2.96
# 9      Horror   2.94
# 11    Mystery   2.80
# 13     Sci-Fi   2.78
# 14   Thriller   2.63
# 12    Romance   2.43
# 1   Adventure   2.38
# 3   Biography   2.37
# 4      Comedy   2.36

# %%
# Plotting on a horizontal bar chart
plot = sns.barplot(data=roi_top_10, y='genre', x='roi_%', orient='h', color='#00A4EF');

# title and axis labels
plot.set_title("Top 10 Genres by Return on Investment")
plot.set_xlabel("Return on Investment")
plot.set_ylabel('')

# This changes the tick labels to show in millions (ex. 50,000,000 -> 50) 
x_tick_labels = ['{:,.0f}'.format(x) + '%' for x in plot.get_xticks()*100]
plot.set_xticks(plot.get_xticks().tolist())
plot.set_xticklabels(x_tick_labels);

# save plot as jpg
plt.savefig("../Images/Top 10 Genres by Return on Investment.jpg", dpi=400, bbox_inches='tight')

# %% [markdown]
# ### Visualizing a Cat Plot with Top 10 Genres that have over 30 observations

# %%
df_all_most_genres
# Out:
#        movie_id      genre  budget_final  domestic_gross  \
# 0     tt0249516     Action   65000000.00               0
# 1     tt0249516  Animation   65000000.00               0
# 2     tt0249516     Comedy   65000000.00               0
# 3     tt0359950  Adventure   90000000.00        58236838
# 4     tt0359950     Comedy   90000000.00        58236838
# ...         ...        ...           ...             ...
# 3307  tt7784604     Horror   10000000.00        44069456
# 3308  tt7784604    Mystery   10000000.00        44069456
# 3309  tt7959026      Crime   50000000.00       103804407
# 3310  tt7959026      Drama   50000000.00       103804407
# 3311  tt7959026   Thriller   50000000.00       103804407
#
#       worldwide_gross_final  profitability
# 0                  73706.00   -64926294.00
# 1                  73706.00   -64926294.00
# 2                  73706.00   -64926294.00
# 3              188133322.00    98133322.00
# 4              188133322.00    98133322.00
# ...                     ...            ...
# 3307            80239658.00    70239658.00
# 3308            80239658.00    70239658.00
# 3309           174804407.00   124804407.00
# 3310           174804407.00   124804407.00
# 3311           174804407.00   124804407.00
#
# [3061 rows x 6 columns]

# %%
# I'll grab list of top 10 genres by worldwide gross
ww_top_10_genres = list(ww_top_10['genre'])
ww_top_10_genres
# Out:
# ['Animation',
#  'Sci-Fi',
#  'Adventure',
#  'Singing',
#  'Action',
#  'Fantasy',
#  'Family',
#  'Comedy',
#  'Western',
#  'Thriller']

# %%
# now I'll filter data frame by only these genres
df_all_most_genres.loc[df_all_most_genres['genre'].isin(ww_top_10_genres)]
# Out:
#        movie_id      genre  budget_final  domestic_gross  \
# 0     tt0249516     Action   65000000.00               0
# 1     tt0249516  Animation   65000000.00               0
# 2     tt0249516     Comedy   65000000.00               0
# 3     tt0359950  Adventure   90000000.00        58236838
# 4     tt0359950     Comedy   90000000.00        58236838
# ...         ...        ...           ...             ...
# 3300  tt7424200  Animation   10000000.00        29790236
# 3301  tt7424200     Comedy   10000000.00        29790236
# 3303  tt7690670     Action   16000000.00        20537137
# 3305  tt7690670   Thriller   16000000.00        20537137
# 3311  tt7959026   Thriller   50000000.00       103804407
#
#       worldwide_gross_final  profitability
# 0                  73706.00   -64926294.00
# 1                  73706.00   -64926294.00
# 2                  73706.00   -64926294.00
# 3              188133322.00    98133322.00
# 4              188133322.00    98133322.00
# ...                     ...            ...
# 3300            28646544.00    18646544.00
# 3301            28646544.00    18646544.00
# 3303            20545116.00     4545116.00
# 3305            20545116.00     4545116.00
# 3311           174804407.00   124804407.00
#
# [1750 rows x 6 columns]

# %%
df_all_most_genres.loc[df_all_most_genres['worldwide_gross_final'] == 0]
# Out:
# Empty DataFrame
# Columns: [movie_id, genre, budget_final, domestic_gross, worldwide_gross_final, profitability]
# Index: []

# %%
# Cat plot of top 10 genres by average worldwide gross
# save data frame to variable
data = df_all_most_genres.loc[df_all_most_genres['genre'].isin(ww_top_10_genres)]

# Cat plot
plot = sns.catplot(data=data, x='genre', y='worldwide_gross_final')

# %% [markdown]
# It is a great visual of the distribution of the values for the genres, but it does not look like it will be a valuable visual for our presentation based on our audience
